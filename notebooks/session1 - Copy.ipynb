# %%
import pandas as pd
pd.read_csv("../data/test.csv")
# Out:
#      Unnamed: 0    ID Gender  Diagnosis  pcm_intensity_sma_minPos  \
# 0             1   103      F          0                  0.038382
# 1             2   103      F          0                  0.054016
# 2             3   103      F          0                  0.124696
# 3             4   103      F          0                  0.099326
# 4             5   103      F          0                  0.025557
# ..          ...   ...    ...        ...                       ...
# 369         370  1445      F          1                  0.000000
# 370         371  1445      F          1                  0.018536
# 371         372  1445      F          1                  0.000000
# 372         373  1445      F          1                  0.013761
# 373         374  1445      F          1                  0.000094
#
#      pcm_intensity_sma_kurtosis  pcm_intensity_sma_iqr1.2  \
# 0                      0.050498                  0.075936
# ...
